# %%
# Notebook to add, change, correct annotations
# conda env: curate_data

# %%
from functions import get_data
from normalize_data import get_unique_index
from run_checks import import_data
import pandas as pd
import os

# %% [markdown]
# # Import & Normalize Data

# %%
normalized_data = "../data/normalized/"
metadata = get_data(normalized_data)

# %%
def normalize_metadata(df, unique_index):
    """
    Function that uses union of all metadata fields to
    add missing fields to each cohort
    """
    df_index = df.iloc[:, 0]
    additional_items = [field for field in list(set(unique_index) - set(df_index)) if not field.startswith('field')]
    
    # get index of fields that should be replaced
    df.reset_index(inplace=True, drop=True)
    startpoint = min(df.loc[df['fieldname'].str.startswith('field', na=False)].index.tolist())
    endpoint = startpoint + len(additional_items) - 1
    df.loc[startpoint:endpoint, 'fieldname'] = additional_items
    df.iloc[startpoint:endpoint, 1:] = 'nd'
    
def add_ajcc_staging(df):
    """
    Function to add ajcc labels to the rows that miss a label,
    but have information about tnm.
    :param data: specific dataset
    :param index: index of rows that are to be modified
    """
    df_T = df.T

    tnm_to_ajcc = {
        'ptis':"0",
        ','.join(["t1n0m0", "t2n0m0"]):'i',
        ','.join(["t3n0m0", "t4n0m0"]):'ii',
        ','.join(['t1n1m0','t2n1m0', 't1n2m0', 't3n1m0', 't4n1m0', 't2n2m0', 't3n2m0']):'iii',
        ','.join([f"t{x}n{y}m1" for  x in range(1,5) for y in range(0,5)]):'iv'
    }

    tnm_index = df_T.loc[(df_T['ajcc'] == "nd") &
                         (df_T['tnm'] != "nd")].index.tolist()
    
    if tnm_index:
        for i in tnm_index:
            tnm_stage = df_T.loc[i, 'tnm']
            for key, ajcc_stage in tnm_to_ajcc.items():
                if tnm_stage in key:
                    df_T.loc[i, 'ajcc'] = ajcc_stage

        print(f"AJCC labels added for {str(len(tnm_index))} samples")

    else:
        print("No labels were added")

    # TODO extract values that are not allowed and curate them manually (e.g. tmn instead of tnm)
    tnm_values = [label for label in df_T['tnm'].tolist() if not label == 'nd']
    tnm_values = list(set([''.join(i for i in label if not i.isdigit()) for label in tnm_values]))
    tnm_values = [label for label in tnm_values if not label == 'tnm']

    if tnm_values:
        print(f"Some tnm labels have an unexpected format. Please Check!\n{tnm_values}")

# %%
# normalize the fields of the metadata headers to the union of all cohorts  in the dataset
metadata_union = get_unique_index(metadata)
for study, data in metadata.items():
    normalize_metadata(data, metadata_union)
    data.set_index("fieldname", inplace=True, drop=False)
    data.index.names = ['index']
    data.drop(columns=['fieldname'], inplace=True)

# %% [markdown]
# # Curate

# %%
# Add AJCC stage for samples that only have tnm annotations
for study, data in metadata.items():
    print(f"\n{study}")
    add_ajcc_staging(data)
# Out:
# YuJ_2015
# No labels were added
#
# ThomasAM_2018a
# No labels were added
#
# VogtmannE_2016
# No labels were added
#
# YachidaS_2019
# No labels were added
#
# WirbelJ_2018
# No labels were added
# Some tnm labels have an unexpected format. Please Check!
# ['tisnm']
#
# FengQ_2015
# AJCC labels added for 45 samples
# Some tnm labels have an unexpected format. Please Check!
# ['ptis']
#
# ThomasAM_2019_c
# No labels were added
#
# ThomasAM_2018b
# No labels were added
#
# GuptaA_2019
# AJCC labels added for 30 samples
# Some tnm labels have an unexpected format. Please Check!
# ['tmn']
#
# ZellerG_2014
# No labels were added
# Some tnm labels have an unexpected format. Please Check!
# ['tnxm']
#
# HanniganGD_2017
# No labels were added

# %%
# modify potential false tnm labels and run ajcc annotating function again
dataset = metadata['GuptaA_2019'].T
dataset.loc[dataset['tnm'] == 't4n2m0', 'ajcc'] = "iii"
dataset.loc[dataset['tnm'] == 't2m0n0', 'ajcc'] = "i"

# %%
# dataset = metadata['FengQ_2015'].T
# dataset.loc[dataset['tnm'].str.startswith('p'), 'ajcc'] # = '0'

# %%
# dataset = metadata['ZellerG_2014'].T
# dataset.loc[dataset['tnm'].str.contains('x'), 'ajcc'] #= "iv"

# %%
dataset = metadata['YachidaS_2019'].T
dataset.loc[:, 'DNA_extraction_kit'] = 'Gnome'

# %%
dataset = metadata['ThomasAM_2019_c'].T
dataset.loc[:, 'DNA_extraction_kit'] = 'Gnome'

# %%
# for study in metadata:
#    print(f"\n{study}\n")
#    print(*[field for field in metadata[study].index if not "field" in field], sep="\n")

# %%
# # check ajcc stage information
# for study in metadata:
#     print(f"\n{study}\n")
#     dataset = metadata[study]
#     if "ajcc" in dataset.index:
#         print(dataset.loc['ajcc'].value_counts())
#         if 'tnm' in dataset.index:
#             dataset_T = dataset.T
#             print(dataset_T.loc[dataset_T['ajcc'] == 'iv', 'tnm'].unique())
#     else:
#         if 'tnm' in dataset.index:
#             print(dataset.loc['tnm'].unique())
#     # elif 'tnm' in dataset.index:
#     #     print(dataset.loc['tnm'].value_counts())

# %%
# # check for abx intake information
# for study in metadata:
#     dataset = metadata[study]
#     if 'antibiotics_current_use' in dataset.index:
#         print(study)
#         print(dataset.loc['antibiotics_current_use'].unique())
#     else:
#         print(study)

# %%
# # check disease labels
# for study in metadata:
#     dataset = metadata[study]
#     print(f"\n{study}\n")
#     print(dataset.loc['disease'].unique())

# %%
# # westernized labels
# for study in metadata:
#     dataset = metadata[study]
#     print(f"\n{study}\n")
#     print(dataset.loc['non_westernized'].unique())

# %%
# # check other annotations
# for study in metadata:
#     dataset = metadata[study]
#     print(f"\n{study}\n")
#     print(dataset.loc['disease_location'].unique())

# %% [markdown]
# ## Exploratory Stuff

# %%
# look at all annotations in general again, per study
for study, dataset in metadata.items():
    print(study)
    dataset = dataset.T
    columns = [col for col in dataset.columns if not col.startswith("field")]
    for column in columns:
        print(dataset[column].value_counts())
        print("\n")
# Out:
# YuJ_2015
# study_name
# YuJ_2015    128
# Name: count, dtype: int64
#
#
# subject_id
# SZAXPI017580-90     1
# SZAXPI017581-93     1
# SZAXPI017582-94     1
# SZAXPI017583-102    1
# SZAXPI017584-108    1
#                    ..
# SZAXPI003412-1      1
# SZAXPI003413-4      1
# SZAXPI003414-3      1
# SZAXPI003415-12     1
# SZAXPI003416-4      1
# Name: count, Length: 128, dtype: int64
#
#
# body_site
# stool    128
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# no    128
# Name: count, dtype: int64
#
#
# study_condition
# CRC        74
# control    54
# Name: count, dtype: int64
#
#
# disease
# CRC        45
# healthy    38
# CRC;T2D    29
# T2D        16
# Name: count, dtype: int64
#
#
# age
# 64    16
# 62     8
# 65     7
# 58     6
# 73     6
# 61     5
# 68     5
# 77     5
# 59     5
# 54     4
# 69     4
# 71     4
# 55     4
# 60     4
# 70     4
# 74     4
# 67     3
# 56     3
# 63     3
# 50     3
# 51     3
# 83     3
# 53     2
# 79     2
# 52     2
# 75     1
# 72     1
# 80     1
# 89     1
# 45     1
# 66     1
# 44     1
# 57     1
# 78     1
# 49     1
# 81     1
# 76     1
# 34     1
# Name: count, dtype: int64
#
#
# age_category
# adult     80
# senior    48
# Name: count, dtype: int64
#
#
# gender
# male      81
# female    47
# Name: count, dtype: int64
#
#
# country
# CHN    128
# Name: count, dtype: int64
#
#
# non_westernized
# no    128
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaHiSeq    128
# Name: count, dtype: int64
#
#
# DNA_extraction_kit
# Qiagen    128
# Name: count, dtype: int64
#
#
# PMID
# 26408641    128
# Name: count, dtype: int64
#
#
# number_reads
# 48287820    1
# 37627614    1
# 50539146    1
# 40240288    1
# 44341480    1
#            ..
# 55761702    1
# 64434830    1
# 52102228    1
# 62456910    1
# 60073374    1
# Name: count, Length: 128, dtype: int64
#
#
# number_bases
# 4645971246    1
# 3592068766    1
# 4977096921    1
# 3861481843    1
# 4339363261    1
#              ..
# 5343486861    1
# 6090719237    1
# 4952005733    1
# 5958738352    1
# 5634395962    1
# Name: count, Length: 128, dtype: int64
#
#
# minimum_read_length
# 30    128
# Name: count, dtype: int64
#
#
# median_read_length
# 100    128
# Name: count, dtype: int64
#
#
# NCBI_accession
# ERR1018297    1
# ERR1018298    1
# ERR1018299    1
# ERR1018300    1
# ERR1018301    1
#              ..
# ERR1018188    1
# ERR1018189    1
# ERR1018190    1
# ERR1018191    1
# ERR1018192    1
# Name: count, Length: 128, dtype: int64
#
#
# curator
# Paolo_Manghi    128
# Name: count, dtype: int64
#
#
# BMI
# 23.7    4
# 24.5    4
# 22.5    4
# 25.6    4
# 21.7    3
#        ..
# 27.7    1
# 21.3    1
# 31.3    1
# 22.8    1
# 18.9    1
# Name: count, Length: 73, dtype: int64
#
#
# diet
# omnivore    128
# Name: count, dtype: int64
#
#
# disease_subtype
# carcinoma    74
# nd           54
# Name: count, dtype: int64
#
#
# tnm
# nd        54
# t3n0m0    23
# t3n1m0    14
# t1n0m0    12
# t2n0m0     6
# t3n2m0     5
# t2n1m0     3
# t3n3m1     2
# t3n1m1     2
# t4n2m0     2
# t3n0m1     2
# t4n1m1     1
# t4n0m0     1
# t4n2m1     1
# Name: count, dtype: int64
#
#
# triglycerides
# nd          26
#  79.7130    13
# 115.1410     9
# 123.9980     8
#  97.4270     8
#  53.1420     7
#  70.8560     6
#  44.2850     5
#  88.5700     5
# 159.4260     4
#  61.9990     4
# 106.2840     4
# 141.7120     3
# 177.1400     2
# 132.8550     2
# 203.7110     2
# 265.7100     2
# 150.5690     1
#  42.5136     1
# 194.8540     1
# 138.1692     1
# 212.5680     1
# 309.9950     1
# 191.3112     1
#  74.3988     1
#  95.6556     1
# 117.7981     1
#  92.1128     1
# 118.6838     1
#  80.5987     1
#  35.4280     1
#  67.3132     1
# 256.8530     1
# 451.7070     1
#  32.7709     1
# Name: count, dtype: int64
#
#
# hdl
# nd          26
#  42.5370    16
#  50.2710    10
#  54.1380    10
#  38.6700     8
#  58.0050     7
#  73.4730     6
#  61.8720     5
#  69.6060     5
#  46.4040     5
#  85.0740     3
#  65.7390     3
#  77.3400     3
#  81.2070     3
#  34.8030     3
#  19.3350     2
#  30.9360     2
#  92.8080     2
# 104.4090     1
#  49.4976     1
#  55.6848     1
#  53.7513     1
# 135.3450     1
#  88.9410     1
#  50.6577     1
#  51.4311     1
#  78.8868     1
# Name: count, dtype: int64
#
#
# ldl
# nd          26
# 127.6110     7
# 100.5420     6
#  92.8080     6
# 116.0100     5
# 123.7440     5
#  81.2070     5
#  58.0050     4
# 112.1430     4
#  96.6750     4
# 146.9460     4
#  73.4730     3
# 119.8770     3
# 143.0790     3
#  61.8720     3
#  85.0740     3
#  88.9410     3
# 166.2810     2
# 135.3450     2
# 104.4090     2
#  27.0690     2
#  69.6060     2
#  77.3400     2
# 158.5470     2
# 108.2760     2
# 154.6800     2
# 139.2120     1
# 131.4780     1
#  65.7390     1
# 193.3500     1
# 150.8130     1
# 185.6160     1
#  54.1380     1
# 165.5076     1
# 201.0840     1
# 170.1480     1
# 157.0002     1
# 162.4140     1
#  46.4040     1
# 189.4830     1
# 177.8820     1
#  78.5001     1
# Name: count, dtype: int64
#
#
# smoker
# nd     54
# no     54
# yes    20
# Name: count, dtype: int64
#
#
# ever_smoker
# nd     54
# no     51
# yes    23
# Name: count, dtype: int64
#
#
# disease_location
# nd        63
# rectum    28
# lc        26
# rc        11
# Name: count, dtype: int64
#
#
# cholesterol
# nd          26
# 170.1480     6
# 177.8820     6
# 193.3500     6
# 189.4830     5
# 224.2860     5
# 158.5470     5
# 162.4140     5
# 220.4190     5
# 232.0200     4
# 201.0840     4
# 197.2170     4
# 174.0150     3
# 204.9510     3
# 146.9460     3
# 154.6800     3
# 228.1530     3
# 255.2220     3
# 127.6110     2
# 239.7540     2
# 135.3450     2
# 112.1430     2
# 235.8870     2
# 166.2810     2
# 332.5620     1
# 104.4090     1
# 278.4240     1
# 123.7440     1
# 247.4880     1
# 131.4780     1
# 150.8130     1
# 208.8180     1
# 116.0100     1
# 139.2120     1
# 259.0890     1
# 181.7490     1
# 243.6210     1
# 100.5420     1
# 274.5570     1
# 185.6160     1
# 163.9608     1
# Name: count, dtype: int64
#
#
# creatinine
# nd     21
#  74     7
#  85     5
#  66     5
#  58     4
#  70     4
#  65     4
#  87     3
#  86     3
#  72     3
#  52     2
#  49     2
#  89     2
#  76     2
#  62     2
#  57     2
#  97     2
#  71     2
#  56     2
#  93     2
# 100     2
#  55     2
#  92     2
#  73     2
#  88     2
#  81     2
#  63     2
#  96     2
#  75     2
#  61     2
#  69     2
# 107     1
# 152     1
#  48     1
#  94     1
# 128     1
#  43     1
#  45     1
# 104     1
# 101     1
# 115     1
#  78     1
#  60     1
#  50     1
#  54     1
#  99     1
#  41     1
# 121     1
# 202     1
#  67     1
#  51     1
#  90     1
#  79     1
#  77     1
#  91     1
# 102     1
#  82     1
#  84     1
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd       28
# 108.0     7
#  97.2     7
#  84.6     6
#  90.0     6
#  93.6     6
#  82.8     5
#  99.0     5
#  91.8     5
#  86.4     4
# 100.8     3
#  95.4     3
# 109.8     3
# 102.6     3
# 131.4     2
#  79.2     2
# 113.4     2
# 126.0     2
# 106.2     2
#  88.2     2
# 151.2     2
# 124.2     2
# 104.4     2
#  77.4     2
# 115.2     2
# 129.6     1
# 140.4     1
# 133.2     1
# 237.6     1
# 147.6     1
# 189.0     1
#  81.0     1
# 172.8     1
# 111.6     1
# 138.6     1
# 178.2     1
# 144.0     1
# 183.6     1
# 169.2     1
# 225.0     1
# Name: count, dtype: int64
#
#
# ajcc
# nd     54
# iii    26
# ii     22
# i      18
# iv      8
# Name: count, dtype: int64
#
#
# ALT
# nd    20
# 15     8
# 19     7
# 16     7
# 20     6
# 27     6
# 21     6
# 12     6
# 18     5
# 17     5
# 22     5
# 10     5
# 13     5
# 23     4
# 25     4
# 24     4
# 11     4
# 28     3
# 31     3
# 35     2
# 14     2
# 33     2
# 69     1
# 34     1
# 55     1
# 30     1
# 68     1
#  9     1
# 39     1
# 40     1
# 43     1
# Name: count, dtype: int64
#
#
# eGFR
# nd        19
#  70.19     2
#  58.85     1
# 117.99     1
#  16.81     1
#           ..
#  86.49     1
#  87.92     1
# 101.33     1
#  59.00     1
#  89.30     1
# Name: count, Length: 109, dtype: int64
#
#
# fobt
# nd    128
# Name: count, dtype: int64
#
#
# brinkman_index
# nd    128
# Name: count, dtype: int64
#
#
# alcohol
# nd    128
# Name: count, dtype: int64
#
#
# alcohol_numeric
# nd    128
# Name: count, dtype: int64
#
#
# location
# nd    128
# Name: count, dtype: int64
#
#
# hba1c
# nd    128
# Name: count, dtype: int64
#
#
# disease_stage
# nd    128
# Name: count, dtype: int64
#
#
# ThomasAM_2018a
# study_name
# ThomasAM_2018a    80
# Name: count, dtype: int64
#
#
# subject_id
# VF50      1
# VF55      1
# VF56      1
# VF60      1
# VF65      1
#          ..
# GF16      1
# GF17      1
# GF18      1
# VF00TL    1
# VF02      1
# Name: count, Length: 80, dtype: int64
#
#
# body_site
# stool    80
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# no    80
# Name: count, dtype: int64
#
#
# study_condition
# CRC        29
# adenoma    27
# control    24
# Name: count, dtype: int64
#
#
# disease
# adenoma                                    16
# CRC                                        15
# healthy                                    14
# CRC;hypertension                            8
# hypercholesterolemia                        5
# adenoma;hypertension                        4
# adenoma;hypercholesterolemia                4
# hypertension                                3
# CRC;hypercholesterolemia                    3
# metastases                                  1
# CRC;cholesterolemia                         1
# hypertension;metastases                     1
# T2D;adenoma                                 1
# adenoma;metastases                          1
# CRC;hypercholesterolemia;hypertension       1
# adenoma;hypercholesterolemia;metastases     1
# CRC;metastases                              1
# Name: count, dtype: int64
#
#
# age
# 77    7
# 64    6
# 70    5
# 67    5
# 58    5
# 63    4
# 60    4
# 61    4
# 69    4
# 78    3
# 71    3
# 57    3
# 68    2
# 83    2
# 84    2
# 59    2
# 53    2
# 66    2
# 80    2
# 74    2
# 75    1
# 55    1
# 73    1
# 50    1
# 62    1
# 81    1
# 82    1
# 76    1
# 56    1
# 79    1
# 49    1
# Name: count, dtype: int64
#
#
# age_category
# senior    45
# adult     35
# Name: count, dtype: int64
#
#
# gender
# male      52
# female    28
# Name: count, dtype: int64
#
#
# country
# ITA    80
# Name: count, dtype: int64
#
#
# non_westernized
# no    80
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaHiSeq    80
# Name: count, dtype: int64
#
#
# DNA_extraction_kit
# Qiagen    80
# Name: count, dtype: int64
#
#
# PMID
# 30936548    80
# Name: count, dtype: int64
#
#
# number_reads
#  80721806    1
#  87057802    1
# 111092954    1
#  75609304    1
#  55363092    1
#             ..
#  86578300    1
#  67202998    1
#  60734114    1
# 208138088    1
#  58176306    1
# Name: count, Length: 80, dtype: int64
#
#
# number_bases
#  8013368722    1
#  8654388646    1
# 11012728796    1
#  7518977822    1
#  5476270020    1
#               ..
#  8612958984    1
#  6647242890    1
#  6033609356    1
# 20599056332    1
#  5781837652    1
# Name: count, Length: 80, dtype: int64
#
#
# minimum_read_length
# 75    80
# Name: count, dtype: int64
#
#
# median_read_length
# 100    80
# Name: count, dtype: int64
#
#
# curator
# Paolo_Manghi;Marisa_Metzger    80
# Name: count, dtype: int64
#
#
# BMI
# 24    11
# 25     9
# 22     8
# 23     7
# 30     7
# 26     7
# 29     5
# 21     5
# nd     4
# 28     4
# 20     3
# 19     2
# 27     2
# 37     1
# 31     1
# 34     1
# 35     1
# 32     1
# 36     1
# Name: count, dtype: int64
#
#
# disease_subtype
# adenocarcinoma    29
# adenoma           27
# nd                24
# Name: count, dtype: int64
#
#
# alcohol
# no    76
# nd     4
# Name: count, dtype: int64
#
#
# smoker
# no    76
# nd     4
# Name: count, dtype: int64
#
#
# ever_smoker
# no    76
# nd     4
# Name: count, dtype: int64
#
#
# diet
# nd    80
# Name: count, dtype: int64
#
#
# fobt
# nd    80
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd    80
# Name: count, dtype: int64
#
#
# brinkman_index
# nd    80
# Name: count, dtype: int64
#
#
# NCBI_accession
# nd    80
# Name: count, dtype: int64
#
#
# ALT
# nd    80
# Name: count, dtype: int64
#
#
# creatinine
# nd    80
# Name: count, dtype: int64
#
#
# ajcc
# nd    80
# Name: count, dtype: int64
#
#
# location
# nd    80
# Name: count, dtype: int64
#
#
# alcohol_numeric
# nd    80
# Name: count, dtype: int64
#
#
# hdl
# nd    80
# Name: count, dtype: int64
#
#
# triglycerides
# nd    80
# Name: count, dtype: int64
#
#
# cholesterol
# nd    80
# Name: count, dtype: int64
#
#
# eGFR
# nd    80
# Name: count, dtype: int64
#
#
# hba1c
# nd    80
# Name: count, dtype: int64
#
#
# ldl
# nd    80
# Name: count, dtype: int64
#
#
# tnm
# nd    80
# Name: count, dtype: int64
#
#
# disease_location
# nd    80
# Name: count, dtype: int64
#
#
# disease_stage
# nd    80
# Name: count, dtype: int64
#
#
# VogtmannE_2016
# study_name
# VogtmannE_2016    110
# Name: count, dtype: int64
#
#
# subject_id
# MMRS99045180ST-27-0-0    1
# MMRS11288076ST-27-0-0    1
# MMRS11664448ST-27-0-0    1
# MMRS11932626ST-27-0-0    1
# MMRS12272136ST-27-0-0    1
#                         ..
# MMRS17963147ST-27-0-0    1
# MMRS18295921ST-27-0-0    1
# MMRS20257302ST-27-0-0    1
# MMRS21365932ST-27-0-0    1
# MMRS24340226ST-27-0-0    1
# Name: count, Length: 110, dtype: int64
#
#
# body_site
# stool    110
# Name: count, dtype: int64
#
#
# study_condition
# control    52
# CRC        52
# nd          6
# Name: count, dtype: int64
#
#
# disease
# healthy    58
# CRC        52
# Name: count, dtype: int64
#
#
# age
# 63    8
# 65    7
# nd    6
# 71    5
# 66    4
# 67    4
# 70    3
# 42    3
# 48    3
# 69    3
# 56    3
# 53    3
# 55    3
# 54    3
# 68    3
# 60    3
# 72    3
# 58    3
# 76    3
# 51    2
# 62    2
# 84    2
# 64    2
# 59    2
# 74    2
# 79    2
# 73    2
# 40    2
# 31    2
# 57    2
# 45    2
# 49    1
# 39    1
# 82    1
# 43    1
# 61    1
# 83    1
# 89    1
# 85    1
# 44    1
# 78    1
# 47    1
# 37    1
# 36    1
# Name: count, dtype: int64
#
#
# age_category
# adult     69
# senior    41
# Name: count, dtype: int64
#
#
# gender
# male      74
# female    30
# nd         6
# Name: count, dtype: int64
#
#
# country
# USA    110
# Name: count, dtype: int64
#
#
# non_westernized
# no    110
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaHiSeq    110
# Name: count, dtype: int64
#
#
# DNA_extraction_kit
# Gnome    110
# Name: count, dtype: int64
#
#
# PMID
# 27171425    110
# Name: count, dtype: int64
#
#
# number_reads
#  43709835    1
#  67924141    1
#  85820299    1
#  44412536    1
#  67377964    1
#             ..
#  67350332    1
#  73085334    1
#  54403239    1
#  72103979    1
#  61178584    1
# Name: count, Length: 110, dtype: int64
#
#
# number_bases
#  3764480856    1
#  5793273464    1
#  7389001007    1
#  3583469911    1
#  5546605088    1
#               ..
#  5570729597    1
#  6384855556    1
#  4649737800    1
#  6082232011    1
#  5032904033    1
# Name: count, Length: 110, dtype: int64
#
#
# minimum_read_length
# 45    55
#  1    36
#  5     7
#  2     7
#  6     5
# Name: count, dtype: int64
#
#
# median_read_length
# 90    45
# 89    37
# 84     7
# 88     7
# 85     5
# 93     5
# 91     3
# 94     1
# Name: count, dtype: int64
#
#
# NCBI_accession
# ERR1293504;ERR1293503;ERR1293502;ERR1293501;ERR1293063;ERR1293062;ERR1293061;ERR1293060    1
# ERR1293500;ERR1293499;ERR1293498;ERR1293497;ERR1293059;ERR1293058;ERR1293057;ERR1293056    1
# ERR1293861;ERR1293860;ERR1293859;ERR1293858;ERR1293420;ERR1293419;ERR1293418;ERR1293417    1
# ERR1293881;ERR1293880;ERR1293879;ERR1293878;ERR1293440;ERR1293439;ERR1293438;ERR1293437    1
# ERR1293877;ERR1293876;ERR1293875;ERR1293874;ERR1293436;ERR1293435;ERR1293434;ERR1293433    1
#                                                                                           ..
# ERR1293621;ERR1293620;ERR1293619;ERR1293618;ERR1293180;ERR1293179;ERR1293178;ERR1293177    1
# ERR1293568;ERR1293567;ERR1293566;ERR1293565;ERR1293127;ERR1293126;ERR1293125;ERR1293124    1
# ERR1293761;ERR1293760;ERR1293759;ERR1293758;ERR1293320;ERR1293319;ERR1293318;ERR1293317    1
# ERR1293653;ERR1293652;ERR1293651;ERR1293650;ERR1293212;ERR1293211;ERR1293210;ERR1293209    1
# ERR1293584;ERR1293583;ERR1293582;ERR1293581;ERR1293143;ERR1293142;ERR1293141;ERR1293140    1
# Name: count, Length: 110, dtype: int64
#
#
# curator
# Paolo_Manghi    110
# Name: count, dtype: int64
#
#
# BMI
# nd          9
# 25.82185    4
# 23.49076    2
# 16.82518    2
# 22.14871    2
#            ..
# 17.43206    1
# 25.68279    1
# 22.59168    1
# 31.37770    1
# 25.38108    1
# Name: count, Length: 96, dtype: int64
#
#
# diet
# nd    110
# Name: count, dtype: int64
#
#
# fobt
# nd    110
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd    110
# Name: count, dtype: int64
#
#
# brinkman_index
# nd    110
# Name: count, dtype: int64
#
#
# ALT
# nd    110
# Name: count, dtype: int64
#
#
# smoker
# nd    110
# Name: count, dtype: int64
#
#
# disease_subtype
# nd    110
# Name: count, dtype: int64
#
#
# alcohol
# nd    110
# Name: count, dtype: int64
#
#
# creatinine
# nd    110
# Name: count, dtype: int64
#
#
# ever_smoker
# nd    110
# Name: count, dtype: int64
#
#
# ajcc
# nd    110
# Name: count, dtype: int64
#
#
# location
# nd    110
# Name: count, dtype: int64
#
#
# alcohol_numeric
# nd    110
# Name: count, dtype: int64
#
#
# hdl
# nd    110
# Name: count, dtype: int64
#
#
# triglycerides
# nd    110
# Name: count, dtype: int64
#
#
# cholesterol
# nd    110
# Name: count, dtype: int64
#
#
# eGFR
# nd    110
# Name: count, dtype: int64
#
#
# hba1c
# nd    110
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# nd    110
# Name: count, dtype: int64
#
#
# ldl
# nd    110
# Name: count, dtype: int64
#
#
# tnm
# nd    110
# Name: count, dtype: int64
#
#
# disease_location
# nd    110
# Name: count, dtype: int64
#
#
# disease_stage
# nd    110
# Name: count, dtype: int64
#
#
# YachidaS_2019
# study_name
# YachidaS_2019    616
# Name: count, dtype: int64
#
#
# subject_id
# sub_12396    1
# sub_10219    1
# sub_10226    1
# sub_10229    1
# sub_10231    1
#             ..
# sub_10334    1
# sub_10318    1
# sub_10322    1
# sub_10323    1
# sub_10324    1
# Name: count, Length: 616, dtype: int64
#
#
# body_site
# stool    616
# Name: count, dtype: int64
#
#
# study_condition
# CRC                          258
# control                      251
# adenoma                       67
# carcinoma_surgery_history     40
# Name: count, dtype: int64
#
#
# disease
# CRC                          258
# healthy                      246
# adenoma                       67
# carcinoma_surgery_history     40
# few_polyps                     5
# Name: count, dtype: int64
#
#
# age
# 73    28
# 69    28
# 64    28
# 70    27
# 66    26
# 65    25
# 67    21
# 68    20
# 74    20
# 72    20
# 63    19
# 62    19
# 61    19
# 58    19
# 59    18
# 71    18
# 55    17
# 76    17
# 78    14
# 60    14
# 51    14
# 77    14
# 75    13
# 52    12
# 49    12
# 57    12
# 54    11
# 47    10
# 46    10
# 50     9
# 48     8
# 45     7
# 40     7
# 44     7
# 53     6
# 42     6
# 56     6
# 38     5
# 41     5
# 37     4
# 43     4
# 79     3
# 30     2
# 32     2
# 34     2
# 35     2
# 28     1
# 39     1
# 31     1
# 21     1
# 27     1
# 33     1
# Name: count, dtype: int64
#
#
# age_category
# adult     347
# senior    269
# Name: count, dtype: int64
#
#
# gender
# male      358
# female    258
# Name: count, dtype: int64
#
#
# country
# JPN    616
# Name: count, dtype: int64
#
#
# non_westernized
# no    616
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaHiSeq    616
# Name: count, dtype: int64
#
#
# PMID
# 31171880    616
# Name: count, dtype: int64
#
#
# number_reads
#  34575120    1
#  84641274    1
#  47470646    1
#  35960640    1
#  63387808    1
#             ..
#  54563590    1
#  69990810    1
#  65573845    1
#  55812132    1
#  30268220    1
# Name: count, Length: 616, dtype: int64
#
#
# number_bases
#  5076142163    1
# 11889864466    1
#  6605044144    1
#  5303768237    1
#  9103761343    1
#               ..
#  7346552018    1
#  9730440555    1
#  9023711379    1
#  7815282738    1
#  4434834196    1
# Name: count, Length: 616, dtype: int64
#
#
# minimum_read_length
# 50    616
# Name: count, dtype: int64
#
#
# median_read_length
# 150    578
# 151     38
# Name: count, dtype: int64
#
#
# curator
# Paolo_Manghi    616
# Name: count, dtype: int64
#
#
# BMI
# 23.66524    5
# 23.87511    5
# 24.60938    5
# 24.60973    4
# 22.22906    4
#            ..
# 25.41090    1
# 28.38480    1
# 25.81663    1
# 26.12245    1
# 19.63112    1
# Name: count, Length: 451, dtype: int64
#
#
# disease_location
# nd                                    358
# rectum                                 95
# right_colon                            83
# left_colon                             69
# left_colon_and_right_colon              7
# left_colon_and_rectum                   2
# rectum_and_left_colon                   1
# rectum,_left_colon_and_right_colon      1
# Name: count, dtype: int64
#
#
# ajcc
# nd     358
# i       75
# 0       73
# iii     51
# ii      36
# iv      23
# Name: count, dtype: int64
#
#
# brinkman_index
#    0    254
#  300     15
#  800     11
#  400     11
#  600     11
#        ...
# 1170      1
#   48      1
#  280      1
#   56      1
#  525      1
# Name: count, Length: 143, dtype: int64
#
#
# alcohol_numeric
#    0.00000    250
#  180.00000     12
#  813.00000     11
#  633.00000     10
#  549.90000      9
#              ...
#   96.96000      1
#  430.00000      1
#  556.50000      1
#  696.00000      1
#  618.35700      1
# Name: count, Length: 204, dtype: int64
#
#
# DNA_extraction_kit
# Gnome    616
# Name: count, dtype: int64
#
#
# diet
# nd    616
# Name: count, dtype: int64
#
#
# fobt
# nd    616
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd    616
# Name: count, dtype: int64
#
#
# NCBI_accession
# nd    616
# Name: count, dtype: int64
#
#
# ALT
# nd    616
# Name: count, dtype: int64
#
#
# smoker
# nd    616
# Name: count, dtype: int64
#
#
# disease_subtype
# nd    616
# Name: count, dtype: int64
#
#
# alcohol
# nd    616
# Name: count, dtype: int64
#
#
# creatinine
# nd    616
# Name: count, dtype: int64
#
#
# ever_smoker
# nd    616
# Name: count, dtype: int64
#
#
# location
# nd    616
# Name: count, dtype: int64
#
#
# hdl
# nd    616
# Name: count, dtype: int64
#
#
# triglycerides
# nd    616
# Name: count, dtype: int64
#
#
# cholesterol
# nd    616
# Name: count, dtype: int64
#
#
# eGFR
# nd    616
# Name: count, dtype: int64
#
#
# hba1c
# nd    616
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# nd    616
# Name: count, dtype: int64
#
#
# ldl
# nd    616
# Name: count, dtype: int64
#
#
# tnm
# nd    616
# Name: count, dtype: int64
#
#
# disease_stage
# nd    616
# Name: count, dtype: int64
#
#
# WirbelJ_2018
# study_name
# WirbelJ_2018    125
# Name: count, dtype: int64
#
#
# subject_id
# MMPU99077057ST         1
# CCMD10032470ST-11-0    1
# CCMD10191450ST-11-0    1
# CCMD11006829ST-21-0    1
# CCMD12232071ST-21-0    1
#                       ..
# CCMD17410933ST-11-0    1
# CCMD18579000ST-11-0    1
# CCMD18829815ST-11-0    1
# CCMD18872694ST-21-0    1
# CCMD19168690ST-11-0    1
# Name: count, Length: 125, dtype: int64
#
#
# body_site
# stool    125
# Name: count, dtype: int64
#
#
# study_condition
# control    65
# CRC        60
# Name: count, dtype: int64
#
#
# disease
# healthy    65
# CRC        60
# Name: count, dtype: int64
#
#
# age
# 59    6
# 53    6
# 61    6
# 64    6
# 66    5
# 62    5
# 60    5
# 75    5
# 50    4
# 63    4
# 73    4
# 51    4
# 58    4
# 57    3
# 69    3
# 67    3
# 45    3
# 56    3
# 34    3
# 65    2
# 55    2
# 41    2
# 72    2
# 74    2
# 42    2
# 81    2
# 49    2
# 70    2
# 79    2
# 37    2
# 48    2
# 85    1
# 80    1
# 29    1
# 46    1
# 87    1
# 44    1
# 76    1
# 71    1
# 28    1
# 77    1
# 35    1
# 54    1
# 68    1
# 43    1
# 52    1
# 84    1
# 90    1
# 39    1
# 30    1
# Name: count, dtype: int64
#
#
# age_category
# adult     86
# senior    39
# Name: count, dtype: int64
#
#
# gender
# male      73
# female    52
# Name: count, dtype: int64
#
#
# country
# DEU    125
# Name: count, dtype: int64
#
#
# non_westernized
# no    125
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaHiSeq    125
# Name: count, dtype: int64
#
#
# DNA_extraction_kit
# Gnome    125
# Name: count, dtype: int64
#
#
# PMID
# 30936547    125
# Name: count, dtype: int64
#
#
# number_reads
# 104954432    1
#  37708359    1
#  34952407    1
#  83456496    1
#  65269931    1
#             ..
#  47437840    1
#  32440106    1
#  34435904    1
#  55300211    1
#  26544429    1
# Name: count, Length: 125, dtype: int64
#
#
# number_bases
#  9173408933    1
#  4639213592    1
#  4351849639    1
#  7310970279    1
#  5370021950    1
#               ..
#  5908657135    1
#  3841428856    1
#  4103990976    1
#  4780095276    1
#  3184004938    1
# Name: count, Length: 125, dtype: int64
#
#
# minimum_read_length
# 45    108
#  1     11
#  2      6
# Name: count, dtype: int64
#
#
# median_read_length
# 139    23
# 138    23
#  92    21
# 140    10
#  91     7
# 135     6
# 114     6
#  93     5
#  89     4
# 113     4
# 112     3
#  88     3
# 137     2
# 108     2
#  94     1
# 141     1
#  90     1
# 136     1
#  96     1
# 116     1
# Name: count, dtype: int64
#
#
# NCBI_accession
# nd            43
# ERR2726493     1
# ERR2726492     1
# ERR2726488     1
# ERR2726487     1
#               ..
# ERR2726436     1
# ERR2726435     1
# ERR2726434     1
# ERR2726433     1
# ERR2726446     1
# Name: count, Length: 83, dtype: int64
#
#
# curator
# Jacob_Wirbel;Paolo_Manghi    82
# Paolo_Manghi                 43
# Name: count, dtype: int64
#
#
# BMI
# 28.0    7
# 27.0    7
# 23.0    6
# 22.0    6
# 26.0    5
#        ..
# 24.4    1
# 26.2    1
# 20.2    1
# 22.6    1
# 26.8    1
# Name: count, Length: 68, dtype: int64
#
#
# tnm
# nd         65
# t3n0m0     19
# t2n0m0      9
# t1n0m0      6
# t3n2m0      4
# t3n1m0      3
# t4n2m1      3
# tisn0m0     3
# t3n1m1      3
# t3n2m1      2
# t3n0m1      2
# t2n1m0      2
# t1n0m1      1
# t4n1m0      1
# t2n0m1      1
# t4n0m0      1
# Name: count, dtype: int64
#
#
# ajcc
# nd     65
# ii     20
# i      15
# iv     13
# iii     9
# 0       3
# Name: count, dtype: int64
#
#
# diet
# nd    125
# Name: count, dtype: int64
#
#
# fobt
# nd    125
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd    125
# Name: count, dtype: int64
#
#
# brinkman_index
# nd    125
# Name: count, dtype: int64
#
#
# ALT
# nd    125
# Name: count, dtype: int64
#
#
# smoker
# nd    125
# Name: count, dtype: int64
#
#
# disease_subtype
# nd    125
# Name: count, dtype: int64
#
#
# alcohol
# nd    125
# Name: count, dtype: int64
#
#
# creatinine
# nd    125
# Name: count, dtype: int64
#
#
# ever_smoker
# nd    125
# Name: count, dtype: int64
#
#
# location
# nd    125
# Name: count, dtype: int64
#
#
# alcohol_numeric
# nd    125
# Name: count, dtype: int64
#
#
# hdl
# nd    125
# Name: count, dtype: int64
#
#
# triglycerides
# nd    125
# Name: count, dtype: int64
#
#
# cholesterol
# nd    125
# Name: count, dtype: int64
#
#
# eGFR
# nd    125
# Name: count, dtype: int64
#
#
# hba1c
# nd    125
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# nd    125
# Name: count, dtype: int64
#
#
# ldl
# nd    125
# Name: count, dtype: int64
#
#
# disease_location
# nd    125
# Name: count, dtype: int64
#
#
# disease_stage
# nd    125
# Name: count, dtype: int64
#
#
# FengQ_2015
# study_name
# FengQ_2015    154
# Name: count, dtype: int64
#
#
# subject_id
# SID532915    1
# SID31004     1
# SID531403    1
# SID531414    1
# SID531416    1
#             ..
# SID31112     1
# SID31129     1
# SID31137     1
# SID31159     1
# SID31160     1
# Name: count, Length: 154, dtype: int64
#
#
# body_site
# stool    154
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# no    154
# Name: count, dtype: int64
#
#
# study_condition
# control    61
# adenoma    47
# CRC        46
# Name: count, dtype: int64
#
#
# disease
# healthy                                 16
# adenoma;fatty_liver;hypertension        14
# fatty_liver;hypertension                13
# CRC                                     13
# CRC;fatty_liver;hypertension            12
# CRC;hypertension                        12
# adenoma;fatty_liver                     12
# hypertension                            11
# T2D;fatty_liver;hypertension             9
# fatty_liver                              8
# adenoma                                  8
# adenoma;hypertension                     8
# CRC;T2D;fatty_liver;hypertension         4
# T2D;fatty_liver                          3
# CRC;fatty_liver                          3
# CRC;T2D;hypertension                     2
# T2D;adenoma;hypertension                 2
# T2D;hypertension                         1
# T2D;adenoma                              1
# T2D;adenoma;fatty_liver;hypertension     1
# T2D;adenoma;fatty_liver                  1
# Name: count, dtype: int64
#
#
# age
# 68    12
# 63    12
# 72    12
# 70    10
# 64     8
# 67     8
# 69     7
# 66     7
# 74     7
# 65     7
# 62     6
# 71     6
# 73     6
# 77     5
# 60     4
# 84     4
# 56     4
# 46     3
# 78     3
# 58     3
# 52     3
# 55     2
# 43     2
# 75     2
# 82     1
# 86     1
# 54     1
# 83     1
# 61     1
# 47     1
# 80     1
# 48     1
# 79     1
# 59     1
# 45     1
# Name: count, dtype: int64
#
#
# age_category
# senior    94
# adult     60
# Name: count, dtype: int64
#
#
# gender
# male      87
# female    67
# Name: count, dtype: int64
#
#
# country
# AUT    154
# Name: count, dtype: int64
#
#
# non_westernized
# no    154
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaHiSeq    154
# Name: count, dtype: int64
#
#
# DNA_extraction_kit
# MoBio    154
# Name: count, dtype: int64
#
#
# PMID
# 25758642    154
# Name: count, dtype: int64
#
#
# number_reads
# 51594677    1
# 40898340    1
# 64766000    1
# 54863689    1
# 54134207    1
#            ..
# 50836391    1
# 40493976    1
# 65162346    1
# 53697448    1
# 48941530    1
# Name: count, Length: 154, dtype: int64
#
#
# number_bases
# 4886998833    1
# 3649611221    1
# 5990057005    1
# 5160814151    1
# 5059776250    1
#              ..
# 4803585209    1
# 3858680926    1
# 6219475696    1
# 4950228947    1
# 4454783107    1
# Name: count, Length: 154, dtype: int64
#
#
# minimum_read_length
# 30    154
# Name: count, dtype: int64
#
#
# median_read_length
# 96    73
# 95    30
# 97    22
# 93    16
# 91     5
# 94     4
# 98     4
# Name: count, dtype: int64
#
#
# NCBI_accession
# ERR710432;ERR710423    1
# ERR688505;ERR688358    1
# ERR688645;ERR688498    1
# ERR688646;ERR688499    1
# ERR688647;ERR688500    1
#                       ..
# ERR688510;ERR688363    1
# ERR688511;ERR688364    1
# ERR688512;ERR688365    1
# ERR688513;ERR688366    1
# ERR688514;ERR688367    1
# Name: count, Length: 154, dtype: int64
#
#
# curator
# Paolo_Manghi;Marisa_Metzger    154
# Name: count, dtype: int64
#
#
# BMI
# 30.00    4
# 22.80    3
# 31.22    3
# 21.70    3
# 22.10    3
#         ..
# 32.25    1
# 26.64    1
# 31.24    1
# 27.43    1
# 31.25    1
# Name: count, Length: 124, dtype: int64
#
#
# diet
# omnivore      138
# vegetarian     10
# nd              6
# Name: count, dtype: int64
#
#
# disease_subtype
# nd                 61
# advancedadenoma    47
# carcinoma          46
# Name: count, dtype: int64
#
#
# tnm
# nd        109
# t2n0m0     10
# t3n0m0      8
# t1n0m0      7
# ptis        7
# t3n1m0      5
# t3n2m0      2
# t4n2m0      2
# t4n1m0      2
# t4n1m1      1
# t4n0m0      1
# Name: count, dtype: int64
#
#
# triglycerides
# 100    3
#  85    3
# 161    3
#  84    3
#  67    3
#       ..
# 209    1
# 165    1
# 160    1
#  50    1
#  56    1
# Name: count, Length: 105, dtype: int64
#
#
# hdl
#  66    8
#  67    6
#  58    5
#  71    5
#  55    5
#  51    5
#  56    4
#  49    4
#  47    4
#  54    4
#  73    4
#  43    4
#  52    4
#  88    4
#  48    4
#  40    4
#  72    3
#  62    3
#  63    3
#  69    3
#  57    3
#  45    3
#  60    3
#  53    3
#  74    3
# nd     3
#  46    3
#  78    3
#  80    3
#  84    3
#  42    3
#  50    2
#  34    2
#  44    2
#  39    2
#  61    2
#  81    2
#  64    2
#  70    2
#  86    1
#  28    1
#  75    1
#  76    1
#  77    1
#  90    1
#  59    1
# 112    1
#  35    1
#  38    1
#  95    1
# 119    1
#  30    1
#  68    1
#  99    1
#  79    1
#  36    1
#  33    1
#  32    1
# Name: count, dtype: int64
#
#
# ldl
# 127    5
# 157    5
# 139    4
# 129    4
#  71    3
#       ..
# 106    1
# 152    1
#  76    1
# 156    1
# 208    1
# Name: count, Length: 94, dtype: int64
#
#
# hba1c
# nd       46
#  5.40     5
#  5.70     4
#  5.58     3
#  5.96     3
#          ..
#  5.75     1
#  5.91     1
#  6.70     1
#  4.70     1
#  7.96     1
# Name: count, Length: 75, dtype: int64
#
#
# fobt
# nd    154
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd    154
# Name: count, dtype: int64
#
#
# brinkman_index
# nd    154
# Name: count, dtype: int64
#
#
# ALT
# nd    154
# Name: count, dtype: int64
#
#
# smoker
# nd    154
# Name: count, dtype: int64
#
#
# alcohol
# nd    154
# Name: count, dtype: int64
#
#
# creatinine
# nd    154
# Name: count, dtype: int64
#
#
# ever_smoker
# nd    154
# Name: count, dtype: int64
#
#
# ajcc
# nd     111
# i       17
# ii       9
# iii      9
# 0        7
# iv       1
# Name: count, dtype: int64
#
#
# location
# nd    154
# Name: count, dtype: int64
#
#
# alcohol_numeric
# nd    154
# Name: count, dtype: int64
#
#
# cholesterol
# nd    154
# Name: count, dtype: int64
#
#
# eGFR
# nd    154
# Name: count, dtype: int64
#
#
# disease_location
# nd    154
# Name: count, dtype: int64
#
#
# disease_stage
# nd    154
# Name: count, dtype: int64
#
#
# ThomasAM_2019_c
# study_name
# ThomasAM_2019_c    80
# Name: count, dtype: int64
#
#
# subject_id
# mix2_N707-N503_CTCTCTAC-TATCCTCT           1
# mix2_N708-N504_CAGAGAGG-AGAGTAGA           1
# mix2_N711-N504_AAGAGGCA-AGAGTAGA           1
# mix20-N702-S501_CGTACTAG-TAGATCGC          1
# mix21_mix22-N705-S502_GGACTCCT-CTCTCTAT    1
#                                           ..
# AHCNMFADXX.N709-S507_GCTACGCT-AAGGAGTA     1
# AHCNMFADXX.N712-S507_GTAGAGGA-AAGGAGTA     1
# AHCT5GADXX.N703-S501_AGGCAGAA-TAGATCGC     1
# BHCNFHADXX.N710-S505_CGAGGCTG-GTAAGGAG     1
# BHCNG3ADXX.N701-S503_TAAGGCGA-TATCCTCT     1
# Name: count, Length: 80, dtype: int64
#
#
# body_site
# stool    80
# Name: count, dtype: int64
#
#
# study_condition
# CRC        40
# control    40
# Name: count, dtype: int64
#
#
# disease
# CRC        40
# healthy    40
# Name: count, dtype: int64
#
#
# age
# 70    7
# 76    6
# 64    4
# 49    4
# 66    4
# 59    4
# 65    4
# 45    3
# 78    3
# 69    3
# 62    3
# 73    3
# 75    3
# 61    2
# 46    2
# 63    2
# 44    2
# 67    2
# 42    2
# 51    2
# 50    1
# 38    1
# 30    1
# 72    1
# 57    1
# 48    1
# 53    1
# 32    1
# 54    1
# 40    1
# 74    1
# 55    1
# 71    1
# 77    1
# 28    1
# Name: count, dtype: int64
#
#
# age_category
# adult     45
# senior    35
# Name: count, dtype: int64
#
#
# gender
# male      45
# female    35
# Name: count, dtype: int64
#
#
# country
# JPN    80
# Name: count, dtype: int64
#
#
# non_westernized
# no    80
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaHiSeq    80
# Name: count, dtype: int64
#
#
# PMID
# 30936548    80
# Name: count, dtype: int64
#
#
# number_reads
# 54782874    1
# 49237538    1
# 46519722    1
# 49830870    1
# 64394050    1
#            ..
# 63143577    1
# 79164015    1
# 14944862    1
# 34545896    1
# 43689354    1
# Name: count, Length: 80, dtype: int64
#
#
# number_bases
#  7892346245    1
#  7167280424    1
#  6692999180    1
#  6545486895    1
#  9052793608    1
#               ..
#  8820156538    1
# 10912549716    1
#  2026501570    1
#  4987063225    1
#  6203986425    1
# Name: count, Length: 80, dtype: int64
#
#
# minimum_read_length
# 75    80
# Name: count, dtype: int64
#
#
# median_read_length
# 150    79
# 149     1
# Name: count, dtype: int64
#
#
# curator
# Giacomo_Damato;Paolo_Manghi    80
# Name: count, dtype: int64
#
#
# BMI
# 22.22222    2
# 25.59374    2
# 22.34778    2
# 22.30815    2
# 17.44493    1
#            ..
# 19.15119    1
# 24.61810    1
# 26.04167    1
# 20.34280    1
# 21.51386    1
# Name: count, Length: 76, dtype: int64
#
#
# ajcc
# iii/iv    40
# nd        39
# 0          1
# Name: count, dtype: int64
#
#
# DNA_extraction_kit
# Gnome    80
# Name: count, dtype: int64
#
#
# diet
# nd    80
# Name: count, dtype: int64
#
#
# fobt
# nd    80
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd    80
# Name: count, dtype: int64
#
#
# brinkman_index
# nd    80
# Name: count, dtype: int64
#
#
# NCBI_accession
# nd    80
# Name: count, dtype: int64
#
#
# ALT
# nd    80
# Name: count, dtype: int64
#
#
# smoker
# nd    80
# Name: count, dtype: int64
#
#
# disease_subtype
# nd    80
# Name: count, dtype: int64
#
#
# alcohol
# nd    80
# Name: count, dtype: int64
#
#
# creatinine
# nd    80
# Name: count, dtype: int64
#
#
# ever_smoker
# nd    80
# Name: count, dtype: int64
#
#
# location
# nd    80
# Name: count, dtype: int64
#
#
# alcohol_numeric
# nd    80
# Name: count, dtype: int64
#
#
# hdl
# nd    80
# Name: count, dtype: int64
#
#
# triglycerides
# nd    80
# Name: count, dtype: int64
#
#
# cholesterol
# nd    80
# Name: count, dtype: int64
#
#
# eGFR
# nd    80
# Name: count, dtype: int64
#
#
# hba1c
# nd    80
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# nd    80
# Name: count, dtype: int64
#
#
# ldl
# nd    80
# Name: count, dtype: int64
#
#
# tnm
# nd    80
# Name: count, dtype: int64
#
#
# disease_location
# nd    80
# Name: count, dtype: int64
#
#
# disease_stage
# nd    80
# Name: count, dtype: int64
#
#
# ThomasAM_2018b
# study_name
# ThomasAM_2018b    60
# Name: count, dtype: int64
#
#
# subject_id
# SBJ01C    1
# SBJ02C    1
# SBJ03H    1
# SBJ04C    1
# SBJ05C    1
# SBJ06C    1
# SBJ07C    1
# SBJ10C    1
# SBJ11C    1
# SBJ12C    1
# SBJ16H    1
# SBJ17H    1
# SBJ18H    1
# SBJ20C    1
# SBJ21H    1
# SBJ22C    1
# SBJ24H    1
# SBJ25C    1
# SBJ26C    1
# SBJ27C    1
# SBJ29C    1
# SBJ31C    1
# SBJ32C    1
# SBJ33C    1
# SBJ34H    1
# SBJ35C    1
# SBJ36C    1
# SBJ37H    1
# SBJ39C    1
# SBJ40C    1
# SBJ42C    1
# SBJ45H    1
# SBJ46H    1
# SBJ47C    1
# SBJ49C    1
# SBJ50C    1
# SBJ51C    1
# SBJ52C    1
# SBJ53C    1
# SBJ55C    1
# SBJ57H    1
# SBJ60H    1
# SBJ61C    1
# SBJ63H    1
# SBJ64C    1
# SBJ65H    1
# SBJ67H    1
# SBJ68H    1
# SBJ69H    1
# SBJ73H    1
# SBJ74H    1
# SBJ75H    1
# SBJ77H    1
# SBJ78H    1
# SBJ79H    1
# SBJ80H    1
# SBJ81H    1
# SBJ82H    1
# SBJ83H    1
# SBJ84H    1
# Name: count, dtype: int64
#
#
# body_site
# stool    60
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# no    60
# Name: count, dtype: int64
#
#
# study_condition
# CRC        32
# control    28
# Name: count, dtype: int64
#
#
# disease
# CRC        32
# healthy    28
# Name: count, dtype: int64
#
#
# age
# 56    5
# 69    4
# 62    4
# 66    4
# 51    3
# 67    3
# 54    3
# 65    3
# 59    3
# 58    3
# 50    2
# 46    2
# 68    2
# 64    2
# 60    2
# 61    2
# 52    1
# 38    1
# 57    1
# 63    1
# 70    1
# 39    1
# 55    1
# 48    1
# nd    1
# 53    1
# 40    1
# 47    1
# 41    1
# Name: count, dtype: int64
#
#
# age_category
# adult     46
# senior    14
# Name: count, dtype: int64
#
#
# gender
# male      39
# female    21
# Name: count, dtype: int64
#
#
# country
# ITA    60
# Name: count, dtype: int64
#
#
# non_westernized
# no    60
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaHiSeq    60
# Name: count, dtype: int64
#
#
# DNA_extraction_kit
# Gnome    60
# Name: count, dtype: int64
#
#
# PMID
# 30936548    60
# Name: count, dtype: int64
#
#
# number_reads
#  43868542    1
#  43898442    1
#  62248461    1
#  36366179    1
#  45139735    1
#  60592176    1
#  61416613    1
#  50329530    1
#  48916828    1
#  39541779    1
#  44260518    1
#  73496867    1
#  27453968    1
#  65119701    1
#  36494066    1
#  23604828    1
#  36804377    1
#  31480824    1
#  41358998    1
#  36706377    1
#  32390885    1
#  13190360    1
#  31790441    1
#  41330625    1
#  38425974    1
#  42524787    1
#  31808126    1
#  10456845    1
#  30131718    1
#  35163513    1
#  59944791    1
#  92522014    1
#  45756759    1
#  33645368    1
#  47699523    1
#  56181745    1
#  24668831    1
#  31846171    1
#  46264048    1
#  35636732    1
#  43890117    1
# 107211531    1
#  63115792    1
#  85236126    1
#  75825202    1
#  41052376    1
#  40868929    1
#  22066831    1
#  33651354    1
#  48210550    1
#  30312297    1
#  24018036    1
#  27868520    1
#  23707897    1
#  35362694    1
#  26117282    1
#  57480181    1
#  37993796    1
#  25118095    1
#  39194253    1
# Name: count, dtype: int64
#
#
# number_bases
#  4347430447    1
#  4346220764    1
#  6153910114    1
#  3600392404    1
#  4468032703    1
#  5988622295    1
#  6077990175    1
#  4979832567    1
#  4859038231    1
#  3893420532    1
#  4398674622    1
#  7310035386    1
#  2727610389    1
#  6471743852    1
#  3613112582    1
#  2336269953    1
#  3645903179    1
#  3117973069    1
#  4101051285    1
#  3637111009    1
#  3210377101    1
#  1306864665    1
#  3148165940    1
#  4096574082    1
#  3806976294    1
#  4205409821    1
#  3151820262    1
#  1034879683    1
#  2982949375    1
#  3483587316    1
#  5954642751    1
#  9200046372    1
#  4548795487    1
#  3342496938    1
#  4733537457    1
#  5573403305    1
#  2448286377    1
#  3158066958    1
#  4591336105    1
#  3534484981    1
#  4354149935    1
# 10646203801    1
#  6265536349    1
#  8455482154    1
#  7519969732    1
#  4072990715    1
#  4055457779    1
#  2190922951    1
#  3342450892    1
#  4788180713    1
#  3010192567    1
#  2383792100    1
#  2766975730    1
#  2355228152    1
#  3511808501    1
#  2593547633    1
#  5705640120    1
#  3774609997    1
#  2493911666    1
#  3891624174    1
# Name: count, dtype: int64
#
#
# minimum_read_length
# 75    60
# Name: count, dtype: int64
#
#
# median_read_length
# 100    60
# Name: count, dtype: int64
#
#
# curator
# Paolo_Manghi    60
# Name: count, dtype: int64
#
#
# BMI
# nd          2
# 25.18079    2
# 26.36560    2
# 28.98201    1
# 20.86112    1
# 22.46003    1
# 27.77693    1
# 27.04164    1
# 31.56167    1
# 24.30249    1
# 29.56195    1
# 25.68956    1
# 23.59700    1
# 28.99931    1
# 20.43817    1
# 31.09789    1
# 19.71332    1
# 28.37370    1
# 27.82931    1
# 27.44060    1
# 25.35154    1
# 26.64360    1
# 20.54989    1
# 29.96161    1
# 23.72281    1
# 20.31250    1
# 27.58020    1
# 17.68979    1
# 19.43301    1
# 38.53061    1
# 24.93372    1
# 24.48980    1
# 34.68609    1
# 19.81784    1
# 22.64219    1
# 20.95717    1
# 28.08433    1
# 29.36576    1
# 29.06977    1
# 21.09375    1
# 21.70513    1
# 23.45092    1
# 25.39062    1
# 32.44997    1
# 25.26757    1
# 34.52709    1
# 28.12500    1
# 28.69265    1
# 21.96712    1
# 23.38435    1
# 21.32513    1
# 24.69136    1
# 26.14928    1
# 23.87511    1
# 28.65014    1
# 26.29758    1
# 24.16327    1
# Name: count, dtype: int64
#
#
# location
# Milan    60
# Name: count, dtype: int64
#
#
# diet
# nd    60
# Name: count, dtype: int64
#
#
# fobt
# nd    60
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd    60
# Name: count, dtype: int64
#
#
# brinkman_index
# nd    60
# Name: count, dtype: int64
#
#
# NCBI_accession
# nd    60
# Name: count, dtype: int64
#
#
# ALT
# nd    60
# Name: count, dtype: int64
#
#
# smoker
# nd    60
# Name: count, dtype: int64
#
#
# disease_subtype
# nd    60
# Name: count, dtype: int64
#
#
# alcohol
# nd    60
# Name: count, dtype: int64
#
#
# creatinine
# nd    60
# Name: count, dtype: int64
#
#
# ever_smoker
# nd    60
# Name: count, dtype: int64
#
#
# ajcc
# nd    60
# Name: count, dtype: int64
#
#
# alcohol_numeric
# nd    60
# Name: count, dtype: int64
#
#
# hdl
# nd    60
# Name: count, dtype: int64
#
#
# triglycerides
# nd    60
# Name: count, dtype: int64
#
#
# cholesterol
# nd    60
# Name: count, dtype: int64
#
#
# eGFR
# nd    60
# Name: count, dtype: int64
#
#
# hba1c
# nd    60
# Name: count, dtype: int64
#
#
# ldl
# nd    60
# Name: count, dtype: int64
#
#
# tnm
# nd    60
# Name: count, dtype: int64
#
#
# disease_location
# nd    60
# Name: count, dtype: int64
#
#
# disease_stage
# nd    60
# Name: count, dtype: int64
#
#
# GuptaA_2019
# study_name
# GuptaA_2019    60
# Name: count, dtype: int64
#
#
# subject_id
# GupDM_A11    1
# GupDM_A15    1
# GupDM_A1     1
# GupDM_A10    1
# GupDM_A12    1
# GupDM_A13    1
# GupDM_A14    1
# GupDM_A2     1
# GupDM_A3     1
# GupDM_A4     1
# GupDM_A5     1
# GupDM_A6     1
# GupDM_A7     1
# GupDM_A8     1
# GupDM_A9     1
# GupDM_HAG    1
# GupDM_HAH    1
# GupDM_HAI    1
# GupDM_HAJ    1
# GupDM_HAK    1
# GupDM_HAL    1
# GupDM_HAM    1
# GupDM_HAN    1
# GupDM_HAO    1
# GupDM_HAP    1
# GupDM_HAR    1
# GupDM_HAT    1
# GupDM_HBR    1
# GupDM_HCL    1
# GupDM_HCM    1
# GupDM_HCN    1
# GupDM_HCO    1
# GupDM_HCP    1
# GupDM_HCQ    1
# GupDM_HCR    1
# GupDM_HCS    1
# GupDM_HCT    1
# GupDM_HCU    1
# GupDM_HCV    1
# GupDM_HCY    1
# GupDM_HDB    1
# GupDM_HDF    1
# GupDM_HP     1
# GupDM_HR     1
# GupDM_HS     1
# GupDM_JA     1
# GupDM_JB     1
# GupDM_JC     1
# GupDM_JD     1
# GupDM_JE     1
# GupDM_JG     1
# GupDM_JH     1
# GupDM_JI     1
# GupDM_JJ     1
# GupDM_JK     1
# GupDM_JL     1
# GupDM_JM     1
# GupDM_JN     1
# GupDM_JO     1
# GupDM_JP     1
# Name: count, dtype: int64
#
#
# body_site
# stool    60
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# no    60
# Name: count, dtype: int64
#
#
# study_condition
# CRC        30
# control    30
# Name: count, dtype: int64
#
#
# disease
# CRC        30
# healthy    30
# Name: count, dtype: int64
#
#
# age
# 58    6
# 62    4
# 26    4
# 25    3
# 57    3
# 71    3
# 59    3
# 50    3
# 23    2
# 61    2
# 64    2
# 24    2
# 66    2
# 56    2
# 65    2
# 53    2
# 49    1
# 72    1
# 55    1
# 48    1
# 41    1
# 75    1
# 28    1
# 29    1
# 22    1
# 52    1
# 30    1
# 47    1
# 54    1
# 60    1
# 67    1
# Name: count, dtype: int64
#
#
# age_category
# adult     52
# senior     8
# Name: count, dtype: int64
#
#
# gender
# female    30
# male      30
# Name: count, dtype: int64
#
#
# country
# IND    60
# Name: count, dtype: int64
#
#
# non_westernized
# no    60
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaNextSeq    60
# Name: count, dtype: int64
#
#
# DNA_extraction_kit
# Qiagen    60
# Name: count, dtype: int64
#
#
# PMID
# 31719139    30
# 30698687    30
# Name: count, dtype: int64
#
#
# number_reads
#  6227234    1
#  9884266    1
# 27687226    1
#  8468208    1
#  6988838    1
#  8067640    1
# 10038762    1
#  7916638    1
#  3283982    1
# 12005312    1
#  7220182    1
#  8086526    1
#  7268266    1
# 11368644    1
#  4665104    1
#  8105478    1
# 10271966    1
# 17519102    1
#  6171104    1
# 10655514    1
#  9271322    1
# 12979624    1
# 13145190    1
# 16932172    1
# 12355776    1
# 10185816    1
#  5952458    1
#  4251494    1
#  7355758    1
#  7352590    1
# 10142394    1
#  9242932    1
#  6704578    1
#  5635222    1
#  6710528    1
#  5521326    1
#  9651384    1
# 11104842    1
# 10996252    1
#  5247522    1
#  4717922    1
#  7376354    1
#  9276878    1
#  8951472    1
# 13442182    1
#  7561246    1
#  6436176    1
#  7854080    1
#  5660024    1
#  6825048    1
#  8460528    1
# 12994616    1
# 11460622    1
#  8350184    1
# 10425236    1
#  9878044    1
# 10328094    1
#  9789278    1
# 11274338    1
# 10400668    1
# Name: count, dtype: int64
#
#
# number_bases
#  883347281    1
# 1384530792    1
# 3808647004    1
# 1174245166    1
#  984235167    1
# 1118699109    1
# 1413415112    1
# 1100929747    1
#  456791391    1
# 1619915370    1
#  997921511    1
# 1064744495    1
#  939363261    1
# 1560459053    1
#  661492622    1
# 1036575018    1
# 1316013844    1
# 2142440783    1
#  773772009    1
# 1344200520    1
# 1203927125    1
# 1688320620    1
# 1696663348    1
# 2103248766    1
# 1610417458    1
# 1327594148    1
#  802869306    1
#  616943354    1
# 1016781080    1
# 1010009755    1
# 1313430561    1
# 1256070078    1
#  914569895    1
#  793309934    1
#  937125039    1
#  754584053    1
# 1363678978    1
# 1433920763    1
# 1517224723    1
#  742418100    1
#  668018094    1
# 1037368291    1
# 1156488365    1
# 1153088906    1
# 1677800044    1
# 1040725254    1
#  882523087    1
# 1057890138    1
#  780426560    1
#  920913556    1
# 1130086052    1
# 1753239492    1
# 1547957943    1
# 1151783466    1
# 1449671956    1
# 1387793557    1
# 1435043694    1
# 1347588954    1
# 1501226163    1
# 1428270555    1
# Name: count, dtype: int64
#
#
# minimum_read_length
# 60    30
# 35    23
# 32     7
# Name: count, dtype: int64
#
#
# median_read_length
# 150    51
# 151     8
# 149     1
# Name: count, dtype: int64
#
#
# NCBI_accession
# SRR8865600    1
# SRR8865596    1
# SRR8865598    1
# SRR8865599    1
# SRR8865601    1
# SRR8865594    1
# SRR8865595    1
# SRR8865597    1
# SRR8865592    1
# SRR8865593    1
# SRR8865584    1
# SRR8865585    1
# SRR8865586    1
# SRR8865587    1
# SRR8865588    1
# SRR5898912    1
# SRR5898911    1
# SRR5898910    1
# SRR5898909    1
# SRR5898908    1
# SRR5898920    1
# SRR5898921    1
# SRR5898922    1
# SRR5898923    1
# SRR5898924    1
# SRR5898925    1
# SRR5898926    1
# SRR5899017    1
# SRR5898966    1
# SRR5898984    1
# SRR5898985    1
# SRR5898986    1
# SRR5898987    1
# SRR5898980    1
# SRR5898981    1
# SRR5898982    1
# SRR5898983    1
# SRR5898978    1
# SRR5898979    1
# SRR5898954    1
# SRR5898950    1
# SRR5898948    1
# SRR5899005    1
# SRR5899007    1
# SRR5899006    1
# SRR8865589    1
# SRR8865590    1
# SRR8865591    1
# SRR8865582    1
# SRR8865583    1
# SRR8865577    1
# SRR8865576    1
# SRR8865579    1
# SRR8865578    1
# SRR8865573    1
# SRR8865572    1
# SRR8865575    1
# SRR8865574    1
# SRR8865581    1
# SRR8865580    1
# Name: count, dtype: int64
#
#
# curator
# Arianna_Bonetti;Paolo_Manghi    60
# Name: count, dtype: int64
#
#
# BMI
# 19.22    2
# 20.08    2
# 22.22    2
# 22.03    2
# 20.03    2
# 17.90    2
# 19.20    2
# 20.80    2
# 21.01    1
# 21.40    1
# 20.32    1
# 18.69    1
# 22.67    1
# 21.21    1
# 20.50    1
# 19.10    1
# 20.83    1
# 18.22    1
# 20.45    1
# 19.14    1
# 23.23    1
# 26.03    1
# 21.26    1
# 22.30    1
# 22.65    1
# 20.82    1
# 21.71    1
# 23.25    1
# 22.90    1
# 36.40    1
# 27.10    1
# 23.00    1
# 19.50    1
# 19.90    1
# 26.80    1
# 25.51    1
# 25.10    1
# 25.70    1
# 18.30    1
# 19.36    1
# 22.97    1
# 19.47    1
# 21.70    1
# 23.81    1
# 18.07    1
# 21.49    1
# 18.96    1
# 18.73    1
# 20.34    1
# 18.33    1
# 19.92    1
# 17.69    1
# Name: count, dtype: int64
#
#
# location
# Bhopal    41
# Kerala    19
# Name: count, dtype: int64
#
#
# disease_subtype
# adenocarcinoma    30
# nd                30
# Name: count, dtype: int64
#
#
# tnm
# nd        30
# t4n1m0     9
# t3n2m0     6
# t2n0m0     5
# t1n0m0     5
# t2m0n0     1
# t3n0m0     1
# t2n2m0     1
# t4n2m0     1
# t2n0m1     1
# Name: count, dtype: int64
#
#
# fobt
# yes    30
# nd     30
# Name: count, dtype: int64
#
#
# disease_stage
# nd     30
# III    17
# I      11
# II      1
# IV      1
# Name: count, dtype: int64
#
#
# disease_location
# nd               30
# rectum           15
# colon             9
# sigmoid colon     6
# Name: count, dtype: int64
#
#
# diet
# nd    60
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd    60
# Name: count, dtype: int64
#
#
# brinkman_index
# nd    60
# Name: count, dtype: int64
#
#
# ALT
# nd    60
# Name: count, dtype: int64
#
#
# smoker
# nd    60
# Name: count, dtype: int64
#
#
# alcohol
# nd    60
# Name: count, dtype: int64
#
#
# creatinine
# nd    60
# Name: count, dtype: int64
#
#
# ever_smoker
# nd    60
# Name: count, dtype: int64
#
#
# ajcc
# nd     30
# iii    17
# i      11
# ii      1
# iv      1
# Name: count, dtype: int64
#
#
# alcohol_numeric
# nd    60
# Name: count, dtype: int64
#
#
# hdl
# nd    60
# Name: count, dtype: int64
#
#
# triglycerides
# nd    60
# Name: count, dtype: int64
#
#
# cholesterol
# nd    60
# Name: count, dtype: int64
#
#
# eGFR
# nd    60
# Name: count, dtype: int64
#
#
# hba1c
# nd    60
# Name: count, dtype: int64
#
#
# ldl
# nd    60
# Name: count, dtype: int64
#
#
# ZellerG_2014
# study_name
# ZellerG_2014    156
# Name: count, dtype: int64
#
#
# subject_id
# FR-552    1
# FR-726    1
# FR-060    1
# FR-568    1
# FR-759    1
#          ..
# FR-169    1
# FR-200    1
# FR-276    1
# FR-460    1
# FR-053    1
# Name: count, Length: 156, dtype: int64
#
#
# body_site
# stool    156
# Name: count, dtype: int64
#
#
# study_condition
# control    61
# CRC        53
# adenoma    42
# Name: count, dtype: int64
#
#
# disease
# healthy    61
# CRC        53
# adenoma    42
# Name: count, dtype: int64
#
#
# age
# 63    14
# 62     8
# 64     8
# 59     8
# 67     7
# 68     7
# 66     7
# 60     5
# 65     5
# 53     5
# 73     5
# 72     5
# 74     4
# 52     4
# 61     4
# 69     4
# 80     3
# 55     3
# 76     3
# 70     3
# 71     3
# 45     3
# 56     3
# 78     2
# 48     2
# 49     2
# 44     2
# 58     2
# 77     2
# 51     2
# 50     2
# 87     2
# 54     2
# 79     2
# 35     1
# 25     1
# 29     1
# 81     1
# 46     1
# 89     1
# 82     1
# 37     1
# 75     1
# 57     1
# 38     1
# 85     1
# 84     1
# Name: count, dtype: int64
#
#
# age_category
# adult     91
# senior    65
# Name: count, dtype: int64
#
#
# gender
# male      87
# female    69
# Name: count, dtype: int64
#
#
# country
# FRA    156
# Name: count, dtype: int64
#
#
# non_westernized
# no    156
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaHiSeq    156
# Name: count, dtype: int64
#
#
# DNA_extraction_kit
# Gnome    156
# Name: count, dtype: int64
#
#
# PMID
# 25432777    156
# Name: count, dtype: int64
#
#
# number_reads
#  69793122    1
#  76003628    1
#  47190574    1
#  87631061    1
#  72027798    1
#             ..
#  61688036    1
#  36441111    1
#  66936604    1
#  68406226    1
#  66245949    1
# Name: count, Length: 156, dtype: int64
#
#
# number_bases
#  5748965241    1
#  6512170482    1
#  3298640533    1
#  7846466205    1
#  6089304969    1
#               ..
#  5175146179    1
#  2826425982    1
#  5667757614    1
#  5817465348    1
#  5739043252    1
# Name: count, Length: 156, dtype: int64
#
#
# minimum_read_length
# 45    124
#  1     26
#  2      4
#  5      2
# Name: count, dtype: int64
#
#
# median_read_length
# 89    30
# 92    30
# 90    24
# 91    20
# 96     9
# 93     8
# 95     6
# 88     6
# 69     5
# 85     4
# 94     3
# 87     3
# 86     2
# 68     2
# 97     2
# 82     1
# 70     1
# Name: count, dtype: int64
#
#
# NCBI_accession
# ERR480914;ERR480913;ERR479418;ERR479417                                            1
# ERR480457;ERR480456;ERR480455;ERR480454;ERR478959;ERR478958;ERR478960;ERR478961    1
# ERR480459;ERR480458;ERR478962;ERR478963                                            1
# ERR480463;ERR480462;ERR480461;ERR480460;ERR478967;ERR478966;ERR478965;ERR478964    1
# ERR480870;ERR480873;ERR480872;ERR480871;ERR479376;ERR479375;ERR479374;ERR479377    1
#                                                                                   ..
# ERR480479;ERR480478;ERR480477;ERR480476;ERR478980;ERR478983;ERR478982;ERR478981    1
# ERR480480;ERR480481;ERR478984;ERR478985                                            1
# ERR480485;ERR480484;ERR480482;ERR480483;ERR478989;ERR478988;ERR478987;ERR478986    1
# ERR480489;ERR480488;ERR480487;ERR480486;ERR478993;ERR478992;ERR478991;ERR478990    1
# ERR480493;ERR480492;ERR480491;ERR480490;ERR478997;ERR478996;ERR478994;ERR478995    1
# Name: count, Length: 156, dtype: int64
#
#
# curator
# Paolo_Manghi    156
# Name: count, dtype: int64
#
#
# BMI
# 24    23
# 25    17
# 23    16
# 26    15
# 22    11
# 21    10
# 30    10
# 20     9
# 27     8
# 28     7
# 29     6
# nd     5
# 32     3
# 37     2
# 19     2
# 31     2
# 34     2
# 33     2
# 18     1
# 39     1
# 15     1
# 40     1
# 36     1
# 17     1
# Name: count, dtype: int64
#
#
# disease_subtype
# nd              61
# carcinoma       53
# smalladenoma    27
# largeadenoma    15
# Name: count, dtype: int64
#
#
# tnm
# nd        103
# t1n0m0      9
# t3n1m1      9
# t4n1m1      8
# t3n1m0      7
# t2n0m0      6
# t3n0m0      6
# t4n1m0      2
# t2n1m1      1
# t4n0m0      1
# t3n0m1      1
# t4n0m1      1
# t2n1m0      1
# t3nxm1      1
# Name: count, dtype: int64
#
#
# fobt
# no     121
# yes     34
# nd       1
# Name: count, dtype: int64
#
#
# ajcc
# nd     103
# iv      21
# i       15
# iii     10
# ii       7
# Name: count, dtype: int64
#
#
# diet
# nd    156
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd    156
# Name: count, dtype: int64
#
#
# brinkman_index
# nd    156
# Name: count, dtype: int64
#
#
# ALT
# nd    156
# Name: count, dtype: int64
#
#
# smoker
# nd    156
# Name: count, dtype: int64
#
#
# alcohol
# nd    156
# Name: count, dtype: int64
#
#
# creatinine
# nd    156
# Name: count, dtype: int64
#
#
# ever_smoker
# nd    156
# Name: count, dtype: int64
#
#
# location
# nd    156
# Name: count, dtype: int64
#
#
# alcohol_numeric
# nd    156
# Name: count, dtype: int64
#
#
# hdl
# nd    156
# Name: count, dtype: int64
#
#
# triglycerides
# nd    156
# Name: count, dtype: int64
#
#
# cholesterol
# nd    156
# Name: count, dtype: int64
#
#
# eGFR
# nd    156
# Name: count, dtype: int64
#
#
# hba1c
# nd    156
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# nd    156
# Name: count, dtype: int64
#
#
# ldl
# nd    156
# Name: count, dtype: int64
#
#
# disease_location
# nd    156
# Name: count, dtype: int64
#
#
# disease_stage
# nd    156
# Name: count, dtype: int64
#
#
# HanniganGD_2017
# study_name
# HanniganGD_2017    81
# Name: count, dtype: int64
#
#
# subject_id
# HanniganGD_2017_A29    1
# HanniganGD_2017_A13    1
# HanniganGD_2017_A14    1
# HanniganGD_2017_A15    1
# HanniganGD_2017_A16    1
#                       ..
# HanniganGD_2017_C05    1
# HanniganGD_2017_C06    1
# HanniganGD_2017_C08    1
# HanniganGD_2017_C09    1
# HanniganGD_2017_C10    1
# Name: count, Length: 81, dtype: int64
#
#
# body_site
# stool    81
# Name: count, dtype: int64
#
#
# antibiotics_current_use
# no    81
# Name: count, dtype: int64
#
#
# study_condition
# control    28
# CRC        27
# adenoma    26
# Name: count, dtype: int64
#
#
# disease
# healthy    28
# CRC        27
# adenoma    26
# Name: count, dtype: int64
#
#
# age
# 51    7
# 61    5
# 64    4
# 63    4
# 69    4
# 65    4
# 59    3
# 58    3
# 52    3
# 47    3
# 50    2
# 68    2
# 37    2
# 56    2
# 43    2
# 49    2
# 55    2
# 71    2
# 57    2
# 73    2
# 75    2
# 54    2
# 45    2
# 70    1
# 88    1
# 48    1
# 60    1
# 42    1
# 35    1
# 44    1
# 76    1
# 46    1
# 82    1
# 62    1
# 53    1
# 72    1
# 67    1
# 80    1
# Name: count, dtype: int64
#
#
# age_category
# adult     59
# senior    22
# Name: count, dtype: int64
#
#
# gender
# male      46
# female    35
# Name: count, dtype: int64
#
#
# country
# USA    54
# CAN    27
# Name: count, dtype: int64
#
#
# non_westernized
# no    81
# Name: count, dtype: int64
#
#
# sequencing_platform
# IlluminaHiSeq    81
# Name: count, dtype: int64
#
#
# DNA_extraction_kit
# MoBio    81
# Name: count, dtype: int64
#
#
# PMID
# 30459201    81
# Name: count, dtype: int64
#
#
# number_reads
#  6133350    1
#  4364706    1
#  3985802    1
#  4399222    1
#  5210030    1
#            ..
#  7180402    1
#  5011214    1
#  5569662    1
# 14630940    1
#  9707904    1
# Name: count, Length: 81, dtype: int64
#
#
# number_bases
#  763336051    1
#  543771467    1
#  496849984    1
#  547643145    1
#  649073139    1
#              ..
#  891959475    1
#  623336859    1
#  693577210    1
# 1816500218    1
# 1208505568    1
# Name: count, Length: 81, dtype: int64
#
#
# minimum_read_length
# 75    81
# Name: count, dtype: int64
#
#
# median_read_length
# 126    79
# 125     2
# Name: count, dtype: int64
#
#
# NCBI_accession
# SRR5665080    1
# SRR5665143    1
# SRR5665142    1
# SRR5665137    1
# SRR5665136    1
#              ..
# SRR5665052    1
# SRR5665057    1
# SRR5665056    1
# SRR5665055    1
# SRR5665054    1
# Name: count, Length: 81, dtype: int64
#
#
# curator
# Paolo_Manghi    81
# Name: count, dtype: int64
#
#
# BMI
# 21.33821    3
# 27.82931    2
# 35.49787    2
# 21.15529    2
# 33.15043    1
#            ..
# 29.75207    1
# 46.36735    1
# 32.90665    1
# 24.38237    1
# 31.60011    1
# Name: count, Length: 76, dtype: int64
#
#
# location
# Houston     27
# Toronto     27
# AnnArbor    15
# Boston      12
# Name: count, dtype: int64
#
#
# fobt
# no     67
# yes    14
# Name: count, dtype: int64
#
#
# diet
# nd    81
# Name: count, dtype: int64
#
#
# fasting_glucose
# nd    81
# Name: count, dtype: int64
#
#
# brinkman_index
# nd    81
# Name: count, dtype: int64
#
#
# ALT
# nd    81
# Name: count, dtype: int64
#
#
# smoker
# nd    81
# Name: count, dtype: int64
#
#
# disease_subtype
# nd    81
# Name: count, dtype: int64
#
#
# alcohol
# nd    81
# Name: count, dtype: int64
#
#
# creatinine
# nd    81
# Name: count, dtype: int64
#
#
# ever_smoker
# nd    81
# Name: count, dtype: int64
#
#
# ajcc
# nd    81
# Name: count, dtype: int64
#
#
# alcohol_numeric
# nd    81
# Name: count, dtype: int64
#
#
# hdl
# nd    81
# Name: count, dtype: int64
#
#
# triglycerides
# nd    81
# Name: count, dtype: int64
#
#
# cholesterol
# nd    81
# Name: count, dtype: int64
#
#
# eGFR
# nd    81
# Name: count, dtype: int64
#
#
# hba1c
# nd    81
# Name: count, dtype: int64
#
#
# ldl
# nd    81
# Name: count, dtype: int64
#
#
# tnm
# nd    81
# Name: count, dtype: int64
#
#
# disease_location
# nd    81
# Name: count, dtype: int64
#
#
# disease_stage
# nd    81
# Name: count, dtype: int64

# %% [markdown]
# # Write curated metadata

# %%
# for study, header in metadata.items():
#     print(header.T['disease'].value_counts())

# %%
# import the normalized datasets
# remove the metadata header
# add the curated metadata header
# write to a new file (which is then transfered to the container)

def get_paths(study, path):
    paths = [os.path.join(path, fname) for fname in os.listdir(path) if study in fname]    
    return  paths

def add_header(df1, df2):
    final_df = pd.concat([df1, df2], ignore_index=True)
    return final_df

def write_csv(final_df, fname):
    final_df.to_csv(fname, index=False)

# %%
for study, header in metadata.items():
    header.reset_index(inplace=True)
    header.rename(columns={"index":"Unnamed: 0"}, inplace=True)
    data_files = get_paths(study, normalized_data)
    for fname in data_files:
        output_name = fname.replace("/normalized/", "/normalized/final/")
        output_name = output_name.replace("normalized_CRC", "CRC")
        data = import_data(fname, skiprows=209)
        final_data = add_header(header, data)
        write_csv(final_data, output_name)
